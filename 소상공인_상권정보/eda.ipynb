# %%
import pandas as pd

# %%
file_path = (
    "./data/raw_data/소상공인시장진흥공단_상가(상권)정보_20240331/소상공인시장진흥공단_상가(상권)정보_서울_202403.csv"
)
df = pd.read_csv(filepath_or_buffer=file_path, low_memory=False)
df.tail()
# Out:
#                       상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 475231  MA0101202310A0038359  마스터부동산중개사무소  NaN        L1      부동산      L102
# 475232  MA0101202310A0035270   그릿뷰티아카데미학원  NaN        P1       교육      P106
# 475233  MA0101202310A0078533        최지원렌탈  NaN        S2    수리·개인      S205
# 475234  MA0101202310A0059884      매직노래연습장  NaN        R1   예술·스포츠      R104
# 475235  MA0101202310A0062853          곱창꾼  NaN        I2       음식      I201
#
#        상권업종중분류명 상권업종소분류코드       상권업종소분류명 표준산업분류코드  ...  \
# 475231  부동산 서비스    L10203     부동산 중개/대리업   L68221  ...
# 475232    기타 교육    P10625  기타 기술/직업 훈련학원   P85669  ...
# 475233  가전제품 수리    S20501       가전제품 수리업   S95310  ...
# 475234   유원지·오락    R10407            노래방   R91223  ...
# 475235       한식    I20109       곱창 전골/구이   I56111  ...
#
#                            건물관리번호       건물명                   도로명주소   구우편번호  \
# 475231  1150010500107970001000001    퀸즈파크나인      서울특별시 강서구 공항대로 247  157805
# ...
