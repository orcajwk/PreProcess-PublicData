# %%
from collections import Counter
from glob import glob

import pandas as pd
from tqdm import tqdm

# %%
file_paths = glob("./data/raw_data/*.csv")

# %%
def read_csv(file_path):
    encodings = ["utf-8", "cp949"]
    for encoding in encodings:
        try:
            df = pd.read_csv(file_path, low_memory=False, encoding=encoding)
            return df, encoding
        except UnicodeDecodeError:
            continue
        except pd.errors.ParserError:
            return None, None

# %%
file_encoding_dict = dict()
file_column_dict = dict()

for file_path in tqdm(file_paths):
    df, encoding = read_csv(file_path)
    if df is not None:
        file_encoding_dict[file_path] = encoding
        file_column_dict[file_path] = df.columns
    else:
        file_encoding_dict[file_path] = "ParseError"
        file_column_dict[file_path] = "ParseError"
# Out:
# 100%|██████████| 77/77 [02:08<00:00,  1.66s/it]

# %%
file_encoding_dict
# Out:
# {'./data/raw_data/국민연금 가입 사업장 내역 2021년 6월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (7).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 2월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (15).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 5월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (23).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 9월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2018년 1월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (19).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (18).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 7월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (22).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2018년 3월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (14).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 4월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (6).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 8월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2018년 7월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (25).csv': 'cp949',
#  './data/raw_data/국민연금공단_국민연금 가입 사업장 내역_20240621.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 3월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2018년 10월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 11월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 12월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 8월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 4월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (1).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (13).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (12).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 6월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 10월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 2월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2018년 9월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2018년 5월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2018년 12월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 11월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (24).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 1월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 4월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (27).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 8월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (11).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (3).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 3월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 7월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 1월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 5월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (2).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 9월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (10).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (26).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2018년 2월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2022년 1월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (17).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (5).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 1월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 9월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 10월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 5월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 2월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (9).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2018년 11월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 12월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2018년 6월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (21).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 10월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (20).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2018년 8월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (8).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2018년 4월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 3월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 7월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (4).csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 12월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 11월.csv': 'cp949',
#  './data/raw_data/국민연금 가입 사업장 내역 (16).csv': 'cp949'}

# %%
Counter(list(file_encoding_dict.values()))
# Out:
# Counter({'cp949': 77})

# %%
columns = [list(column) for column in file_column_dict.values()]

# %%
# Counter({'자료생성년월': 32,
#          ' 사업장명': 28,
#          ' 사업자등록번호': 28,
#          ' 사업장가입상태코드 1 등록 2 탈퇴': 28,,
#          '사업장가입상태코드 1:등록2:탈퇴 WKPL_JNNG_STCD VARCHAR(1)': 27,
#          '우편번호 ZIP\tVARCHAR(6)': 27,
#          '사업장지번상세주소 WKPL_LTNO_DTL_ADDR\tVARCHAR(300)': 27,
#          '사업장도로명상세주소 WKPL_ROAD_NM_DTL_ADDR VARCHAR(300)': 27,
# ...
#          ' 상실가입자수(납부예외 포함  전달 고지대상자와 비교하므로 실제 퇴사자와 상이할 수 있음(초일이 아닌 상실자는 다음달 상실자수에 반영) 국민연금법 제6조 8조 동법 시행령 제18조에 의거 60세 도달하거나 퇴직연금수급자 조기노령연금 수급권을 취득한 자는 가입대상에서 제외되며 18세미만 기초수급자는 본인희망에 의해 제외될 수 있음)': 18,
#          ' 가입자수': 10,
#          ' 당월고지금액': 10,
#          ' 신규취득자수': 10,
#          ' 상실가입자수': 10})

# %%
Counter(sum(columns,[]))
# Out:
# Counter({'자료생성년월': 32,
#          ' 사업장명': 28,
#          ' 사업자등록번호': 28,
#          ' 사업장가입상태코드 1 등록 2 탈퇴': 28,
#          ' 우편번호': 28,
#          ' 사업장지번상세주소': 28,
#          ' 사업장도로명상세주소': 28,
#          ' 고객법정동주소코드': 28,
#          ' 고객행정동주소코드': 28,
#          ' 법정동주소광역시도코드': 28,
#          ' 법정동주소광역시시군구코드': 28,
#          ' 법정동주소광역시시군구읍면동코드': 28,
#          ' 사업장형태구분코드 1 법인 2 개인': 28,
#          ' 사업장업종코드': 28,
#          ' 사업장업종코드명': 28,
#          ' 적용일자': 28,
#          ' 재등록일자': 28,
#          ' 탈퇴일자': 28,
#          '자료생성년월 DATA_CRT_YM VARCHAR(6)': 27,
#          '사업장명 WKPL_NM\tVARCHAR(100)': 27,
#          '사업자등록번호 BZOWR_RGST_NO VARCHAR(10)': 27,
#          '사업장가입상태코드 1:등록2:탈퇴 WKPL_JNNG_STCD VARCHAR(1)': 27,
#          '우편번호 ZIP\tVARCHAR(6)': 27,
#          '사업장지번상세주소 WKPL_LTNO_DTL_ADDR\tVARCHAR(300)': 27,
#          '사업장도로명상세주소 WKPL_ROAD_NM_DTL_ADDR VARCHAR(300)': 27,
#          '고객법정동주소코드 CUST_LDONG_ADDR_CD\tVARCHAR(10)': 27,
#          '고객행정동주소코드 CUST_PADONG_ADDR_CD\tVARCHAR(10)': 27,
#          '법정동주소광역시도코드 LDONG_ADDR_MGPL_DG_CD\tVARCHAR(2)': 27,
#          '법정동주소광역시시군구코드 LDONG_ADDR_MGPL_SGGU_CD\tVARCHAR(5)': 27,
#          '법정동주소광역시시군구읍면동코드 LDONG_ADDR_MGPL_SGGU_EMD_CD\tVARCHAR(8)': 27,
#          '사업장형태구분코드 1:법인2:개인 WKPL_STYL_DVCD\tVARCHAR(1)': 27,
#          '사업장업종코드 WKPL_INTP_CD\t국세청업종코드참조 VARCHAR(6)': 27,
#          '사업장업종코드명 VLDT_VL_KRN_NM VARCHAR(200)': 27,
#          '적용일자 ADPT_DT VARCHAR(8)': 27,
#          '재등록일자 RRG_DT\tVARCHAR(8)': 27,
#          '탈퇴일자 SCSN_DT VARCHAR(8)': 27,
#          '가입자수 JNNGP_CNT INTEGER': 27,
#          '당월고지금액 CRRMM_NTC_AMT\tINTEGER': 27,
#          '신규취득자수 NW_ACQZR_CNT\tINTEGER': 27,
#          '상실가입자수 LSS_JNNGP_CNT\tINTEGER': 27,
#          '사업장명': 22,
#          '사업자등록번호': 22,
#          '사업장가입상태코드 1 등록 2 탈퇴': 22,
#          '우편번호': 22,
#          '사업장지번상세주소': 22,
#          '사업장도로명상세주소': 22,
#          '고객법정동주소코드': 22,
#          '고객행정동주소코드': 22,
#          '법정동주소광역시도코드': 22,
#          '법정동주소광역시시군구코드': 22,
#          '법정동주소광역시시군구읍면동코드': 22,
#          '사업장형태구분코드 1 법인 2 개인': 22,
#          '사업장업종코드': 22,
#          '사업장업종코드명': 22,
#          '적용일자': 22,
#          '재등록일자': 22,
#          '탈퇴일자': 22,
#          '가입자수': 22,
#          '당월고지금액': 22,
#          '신규취득자수': 22,
#          '상실가입자수': 22,
#          '자료생성년월(자격마감일(사유발생일이 속하는 달의 다음달 15일)까지 신고분 반영)': 18,
#          ' 가입자수(고지인원 수 포함)': 18,
#          ' 당월고지금액( 국민연금법 시행령 제5조에 의거 기준소득월액 상한액 적용으로 실제소득과 고지금액은 상이할 수 있음  상한액 2019.7.~2020.6. 4860000원(2019.7.1.기준) 상한액 2020.7.~2021.6. 5030000원(2020.7.1.기준) 상한액 2021.7.~2022.6.  5240000원(2021.7.1.기준) )': 18,
#          ' 신규취득자수(납부재개 포함  전달 고지대상자와 비교하므로 실제 취득자와 상이할 수 있음(초일취득 고지 초일이 아닌경우. 미고지(다음달 취득자수에 반영))': 18,
#          ' 상실가입자수(납부예외 포함  전달 고지대상자와 비교하므로 실제 퇴사자와 상이할 수 있음(초일이 아닌 상실자는 다음달 상실자수에 반영) 국민연금법 제6조 8조 동법 시행령 제18조에 의거 60세 도달하거나 퇴직연금수급자 조기노령연금 수급권을 취득한 자는 가입대상에서 제외되며 18세미만 기초수급자는 본인희망에 의해 제외될 수 있음)': 18,
#          ' 가입자수': 10,
#          ' 당월고지금액': 10,
#          ' 신규취득자수': 10,
#          ' 상실가입자수': 10})

# %%
df.columns = [col.strip().split()[0].split("(")[0] for col in df.columns]

# %%
df['자료생성년월'].mode().iloc[0]
# Out:
# '2019-01'

# %%
Counter([col.strip().split()[0].split("(")[0] for col in sum(columns, [])])
# Out:
# Counter({'자료생성년월': 65,
#          '사업장명': 65,
#          '사업자등록번호': 65,
#          '사업장가입상태코드': 65,
#          '우편번호': 65,
#          '사업장지번상세주소': 65,
#          '사업장도로명상세주소': 65,
#          '고객법정동주소코드': 65,
#          '고객행정동주소코드': 65,
#          '법정동주소광역시도코드': 65,
#          '법정동주소광역시시군구코드': 65,
#          '법정동주소광역시시군구읍면동코드': 65,
#          '사업장형태구분코드': 65,
#          '사업장업종코드': 65,
#          '사업장업종코드명': 65,
#          '적용일자': 65,
#          '재등록일자': 65,
#          '탈퇴일자': 65,
#          '가입자수': 65,
#          '당월고지금액': 65,
#          '신규취득자수': 65,
#          '상실가입자수': 65})

# %%
len(file_paths)
# Out:
# 65

# %%
sorted(file_paths)
# Out:
# ['./data/raw_data/국민연금 가입 사업장 내역 (1).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (10).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (11).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (12).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (13).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (14).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (15).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (16).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (17).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (18).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (19).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (2).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (20).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (21).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (22).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (23).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (24).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (25).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (26).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (27).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (3).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (4).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (5).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (6).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (7).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (8).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 (9).csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 10월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 11월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 12월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 1월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 2월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 3월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 4월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 5월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 6월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 7월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 8월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2019년 9월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 10월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 11월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 12월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 1월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 2월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 3월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 4월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 5월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 7월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 8월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2020년 9월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 10월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 11월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 12월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 1월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 2월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 3월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 4월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 5월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 6월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 7월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 8월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2021년 9월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역 2022년 1월.csv',
#  './data/raw_data/국민연금 가입 사업장 내역.csv',
#  './data/raw_data/국민연금공단_국민연금 가입 사업장 내역_20240621.csv']

# %%
pd.read_csv("./data/raw_data/국민연금 가입 사업장 내역 2019년 2월.csv", encoding="cp949")
# Out:
# /var/folders/c4/g1mnjj6x6d1_205z6bzrtjr80000gn/T/ipykernel_19911/1760000869.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv( './data/raw_data/국민연금 가입 사업장 내역 2019년 2월.csv',encoding='cp949')
#        자료생성년월 DATA_CRT_YM VARCHAR(6)  \
# 0                            2019-01
# 1                            2019-01
# 2                            2019-01
# 3                            2019-01
# 4                            2019-01
# ...                              ...
# 497452                       2019-01
# 497453                       2019-01
# 497454                       2019-01
# 497455                       2019-01
# 497456                       2019-01
#
#                                사업장명 WKPL_NM\tVARCHAR(100)  \
# 0                                                  서등주식회사
# 1                                               (주)니프코코리아
# 2                                               글로웨이 주식회사
# 3                                                 신일기업(주)
# 4                                                디에스디엘(주)
# ...                                                   ...
# 497452  삼성전자로지텍(주) (일용)천안상록리조트리모델링공사지급자재(시스템에어컨옵션품목)구매 설치
# 497453                        수만건설（주）-(일용) 삼선초 본관동 외벽개선공사
# 497454              대선이엔씨(주)-(일용)요진건설 이태원 호텔캐피탈 리모델링 전기공사
# 497455        주원종합건설（주）/(일용)상명리창조적마을만들기사업노인회관리모델링및포제단건축공사
# 497456                     주식회사서경정보기술-(일용)여성회관 리모델링공사(통신)
#
#         사업자등록번호 BZOWR_RGST_NO VARCHAR(10)  \
# 0                                  102812
# 1                                  211814
# 2                                  110812
# 3                                  201810
# 4                                  104811
# ...                                   ...
# 497452                             124815
# 497453                             110817
# 497454                             202810
# 497455                             616813
# 497456                             204864
#
#         사업장가입상태코드 1:등록2:탈퇴 WKPL_JNNG_STCD VARCHAR(1) 우편번호 ZIP\tVARCHAR(6)  \
# 0                                                  1                03740
# 1                                                  1                31409
# 2                                                  1                06072
# 3                                                  1                04537
# 4                                                  1                04526
# ...                                              ...                  ...
# 497452                                             1                31251
# 497453                                             1                02863
# 497454                                             1                04392
# 497455                                             1              695-930
# 497456                                             1                15829
#
#        사업장지번상세주소 WKPL_LTNO_DTL_ADDR\tVARCHAR(300)  \
# 0                                  서울특별시 서대문구 미근동
# 1                                    충청남도 아산시 둔포면
# 2                                   서울특별시 강남구 청담동
# 3                                  서울특별시 중구 충무로2가
# 4                                 서울특별시 중구 남대문로4가
# ...                                           ...
# 497452                           충청남도 천안시 동남구 수신면
# 497453                            서울특별시 성북구 삼선동3가
# 497454                             서울특별시 용산구 이태원동
# 497455                            제주특별자치도 제주시 한림읍
# 497456                                경기도 군포시 금정동
#
#        사업장도로명상세주소 WKPL_ROAD_NM_DTL_ADDR VARCHAR(300)  \
# 0                                  서울특별시 서대문구 충정로6안길
# 1                                충청남도 아산시 둔포면 아산밸리남로
# 2                                 서울특별시 강남구 영동대로137길
# 3                                       서울특별시 중구 퇴계로
# 4                                      서울특별시 중구 세종대로
# ...                                              ...
# 497452                          충청남도 천안시 동남구 수신면 수신로
# 497453                              서울특별시 성북구 보문로29길
# 497454                                 서울특별시 용산구 장문로
# 497455
# 497456                                  경기도 군포시 청백리길
#
#         고객법정동주소코드 CUST_LDONG_ADDR_CD\tVARCHAR(10)  \
# 0                                      1141010400
# 1                                      4420036032
# 2                                      1168010400
# 3                                      1114012500
# 4                                      1114011700
# ...                                           ...
# 497452                                 4413135026
# 497453                                 1129011300
# 497454                                 1117013000
# 497455                                 5011025030
# 497456                                 4141010500
#
#        고객행정동주소코드 CUST_PADONG_ADDR_CD\tVARCHAR(10)  \
# 0                                      1141056500
# 1                                      4420036032
# 2                                      1168056500
# 3                                      1114055000
# 4                                      1114054000
# ...                                           ...
# 497452                                 4413135026
# 497453                                 1129055500
# 497454                                 1117065000
# 497455                                 5011025030
# 497456                                 4141057000
#
#         법정동주소광역시도코드 LDONG_ADDR_MGPL_DG_CD\tVARCHAR(2)  ...  \
# 0                                                  11  ...
# 1                                                  44  ...
# 2                                                  11  ...
# 3                                                  11  ...
# 4                                                  11  ...
# ...                                               ...  ...
# 497452                                             44  ...
# 497453                                             11  ...
# 497454                                             11  ...
# 497455                                             50  ...
# 497456                                             41  ...
#
#         사업장형태구분코드 1:법인2:개인 WKPL_STYL_DVCD\tVARCHAR(1)  \
# 0                                                   1
# 1                                                   1
# 2                                                   1
# 3                                                   1
# 4                                                   1
# ...                                               ...
# 497452                                              1
# 497453                                              1
# 497454                                              1
# 497455                                              1
# 497456                                              1
#
#         사업장업종코드 WKPL_INTP_CD\t국세청업종코드참조 VARCHAR(6)  \
# 0                                           222102
# 1                                           252901
# 2                                           452101
# 3                                           381002
# 4                                           701201
# ...                                            ...
# 497452                                      630201
# 497453                                      452102
# 497454                                      452104
# 497455                                      451200
# 497456                                      452104
#
#         사업장업종코드명 VLDT_VL_KRN_NM VARCHAR(200) 적용일자 ADPT_DT VARCHAR(8)  \
# 0                                    스크린 인쇄업              1988-01-01
# 1                          포장용 플라스틱 성형용기 제조업              1988-01-01
# 2                            미장  타일 및 방수 공사업              1988-01-01
# 3                                        NaN              1988-01-01
# 4                       비주거용 건물 임대업(점포  자기땅)              1988-01-01
# ...                                      ...                     ...
# 497452                                일반 창고업              2018-12-27
# 497453                           유리 및 창호 공사업              2018-12-28
# 497454                         배관 및 냉ㆍ난방 공사업              2019-01-01
# 497455                         기타 토목 시설물 건설업              2018-10-24
# 497456                         배관 및 냉ㆍ난방 공사업              2018-04-20
#
#        재등록일자 RRG_DT\tVARCHAR(8) 탈퇴일자 SCSN_DT VARCHAR(8)  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 497452                      NaN                     NaN
# 497453                      NaN                     NaN
# 497454                      NaN                     NaN
# 497455                      NaN                     NaN
# 497456                      NaN                     NaN
#
#        가입자수 JNNGP_CNT INTEGER 당월고지금액 CRRMM_NTC_AMT\tINTEGER  \
# 0                           4                        837880
# 1                         667                     276233220
# 2                           3                       1035900
# 3                          21                       6480400
# 4                          23                       5046960
# ...                       ...                           ...
# 497452                      4                        868560
# 497453                      5                       1703700
# 497454                      3                        819900
# 497455                      7                       1532700
# 497456                      3                       1067400
#
#         신규취득자수 NW_ACQZR_CNT\tINTEGER  상실가입자수 LSS_JNNGP_CNT\tINTEGER
# 0                                  0                              1
# 1                                  0                              6
# 2                                  0                              0
# 3                                  0                              0
# 4                                  3                              1
# ...                              ...                            ...
# 497452                             4                              0
# 497453                             5                              2
# 497454                             3                              1
# 497455                             7                              0
# 497456                             3                              3
#
# [497457 rows x 22 columns]
